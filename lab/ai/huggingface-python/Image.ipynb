# %%
# !pip install pillow
# !pip install numpy
# !pip install matplotlib

# %%
import PIL
from PIL import Image

# %%
pic = Image.open("Puppy.png")

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=625x500>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
# from PIL import PngImagePlugin
PIL.PngImagePlugin.PngImageFile
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
import numpy as np

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (500, 625, 4)

# %%
# pic_arr
import matplotlib.pyplot as plt

# %%
plt.imshow(pic_arr)

# %%
# pic_red[:,:,1].shape
pic_red = pic_arr.copy()
pic_red[:,:,1] = 0
pic_red[:,:,2] = 0
plt.imshow(pic_red)

# %%
# !pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 26.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 29.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# ...

# %%
import cv2

# %%
img = cv2.imread("Puppy.png")

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb) # open cv BGR, matplotlib in RGB

# %%
img_gray = cv2.imread("Puppy.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap="gray") # open cv BGR, matplotlib in RGB
